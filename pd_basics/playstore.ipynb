# %%
import pandas as pd

# %%
playstore = pd.read_csv("playstore.csv", index_col=0)

# %%
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Сохраните в переменные 'data_head' и 'data_tail' первые 3 и последние 3 строки датафрейма соответсвенно.

# %%
data_head = playstore.head(3)
data_tail = playstore.tail(3)

# %%
data_head
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size    Installs  Type Price Content Rating  \
# 0      159   19M     10,000+  Free     0       Everyone
# 1      967   14M    500,000+  Free     0       Everyone
# 2    87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
data_tail
# Out:
#                                                  App             Category  \
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10837     NaN        3                9.5M       1,000+  Free     0
# 10838     4.5      114  Varies with device       1,000+  Free     0
# 10839     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10837       Everyone            Medical  January 20, 2017                 1.0
# 10838     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10839       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10837          2.2 and up
# ...

# %% [markdown]
# Сохраните в переменные 'n_col' и 'n_row' количество строк и столбцов в датафрейме соответсвенно.

# %%
n_row = playstore.shape[0]

# %%
n_col = playstore.shape[1]

# %%
print(f"Количество записей: {n_row}, количество колонок: {n_col}")
# Out:
# Количество записей: 10840, количество колонок: 13

# %% [markdown]
# Количество уникальных приложений.

# %%
playstore.App.nunique()
# Out:
# 9659

# %% [markdown]
# Посчитать количество пропущенных значений в колонке с рейтингом приложений.

# %%
rating_missing = playstore.Rating.isna().sum()

# %%
rating_missing = len(playstore) - playstore.Rating.count()

# %% [markdown]
# Объединить 3 датафрейма.

# %%
data_6_8 = playstore.loc[5:7]
data_16_19 = playstore.loc[15:18]

# %%
new_playstore = pd.concat([data_head, data_6_8, data_16_19])[['App', 'Size', 'Genres', 'Current Ver']]

# %%
new_playstore
# Out:
#                                                   App  Size  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook   19M
# 1                                 Coloring book moana   14M
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  8.7M
# 5                          Paper flowers instructions  5.6M
# 6             Smoke Effect Photo Maker - Smoke Editor   19M
# 7                                    Infinite Painter   29M
# 15                    Learn To Draw Kawaii Characters  2.7M
# 16       Photo Designer - Write your name with shapes  5.5M
# 17                           350 Diy Room Decor Ideas   17M
# 18                      FlipaClip - Cartoon animation   39M
#
#                        Genres Current Ver
# 0                Art & Design       1.0.0
# 1   Art & Design;Pretend Play       2.0.0
# 2                Art & Design       1.2.4
# 5                Art & Design         1.0
# 6                Art & Design         1.1
# 7                Art & Design    6.1.61.1
# ...

# %% [markdown]
# Убрать дубликаты приложений 'App' из датафрейма 'playstore'.

# %%
unique_playstore = playstore.drop_duplicates(subset=['App'])

# %%
unique_playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# В этом задании названия колонок необходимо привести к стандартному виду — все буквы должны быть нижнего регистра, а пробелы должны быть заменены на нижние подчеркивания.

# %%
unique_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            9659 non-null   object
#  5   Installs        9659 non-null   object
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
unique_playstore.columns = [col.replace(' ', '_').lower() for col in unique_playstore.columns]

# %%
unique_playstore
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Давайте посмотрим на долю платных и бесплатных приложений. В качестве ответа введите долю бесплатных приложений. Ответ округлите до сотых, в качестве десятичного разделителя используйте точку.

# %%
print(round(unique_playstore[~(unique_playstore['type'] == "Free")]['app'].count() / unique_playstore['app'].count(), 2))
print(round(unique_playstore[unique_playstore['type'] == "Free"]['app'].count() / unique_playstore['app'].count(), 2))
# Out:
# 0.08
# 0.92

# %% [markdown]
# Отберите из датафрейма только те приложения, которые относятся к образовательной категории (EDUCATION) и с количеством отзывов пользователей более 1000. Сохраните новый датафрейм в переменную education_playstore.

# %%
unique_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             9659 non-null   object
#  1   category        9659 non-null   object
#  2   rating          8196 non-null   float64
#  3   reviews         9659 non-null   int64
#  4   size            9659 non-null   object
#  5   installs        9659 non-null   object
#  6   type            9658 non-null   object
#  7   price           9659 non-null   float64
#  8   content_rating  9659 non-null   object
#  9   genres          9659 non-null   object
#  10  last_updated    9659 non-null   object
#  11  current_ver     9651 non-null   object
#  12  android_ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
education_playstore = unique_playstore[(unique_playstore['category'] == "EDUCATION") & (unique_playstore['reviews'] > 1000)].reset_index(drop=True)

# %%
education_playstore.head()
# Out:
#                                                  app   category  rating  \
# 0                     Duolingo: Learn Languages Free  EDUCATION     4.7
# 1                                                TED  EDUCATION     4.6
# 2  English Communication - Learn English for Chin...  EDUCATION     4.7
# 3                                       Khan Academy  EDUCATION     4.6
# 4                         Learn English with Wlingua  EDUCATION     4.7
#
#    reviews                size      installs  type  price content_rating  \
# 0  6289924  Varies with device  100,000,000+  Free    0.0       Everyone
# 1   181893                 18M   10,000,000+  Free    0.0   Everyone 10+
# 2     2544                 18M      100,000+  Free    0.0       Everyone
# 3    85375                 21M    5,000,000+  Free    0.0       Everyone
# 4   314299                3.3M   10,000,000+  Free    0.0       Everyone
#
#                 genres       last_updated         current_ver  \
# ...

# %% [markdown]
# Убрать лишние символы из колонки с ценой.

# %%
unique_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             9659 non-null   object
#  1   category        9659 non-null   object
#  2   rating          8196 non-null   float64
#  3   reviews         9659 non-null   int64
#  4   size            9659 non-null   object
#  5   installs        9659 non-null   object
#  6   type            9658 non-null   object
#  7   price           9659 non-null   float64
#  8   content_rating  9659 non-null   object
#  9   genres          9659 non-null   object
#  10  last_updated    9659 non-null   object
#  11  current_ver     9651 non-null   object
#  12  android_ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
unique_playstore['price'].value_counts()
# Out:
# price
# 0.00      8903
# 0.99       145
# 2.99       124
# 1.99        73
# 4.99        70
#           ...
# 18.99        1
# 389.99       1
# 19.90        1
# 1.75         1
# 1.04         1
# Name: count, Length: 92, dtype: int64

# %%
unique_playstore
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Сделать сводную таблицу.

# %%
unique_playstore.groupby(['category', 'type']
).agg(
    mean_price = ('price', 'mean'),
    mean_rating = ('rating', 'mean')
)
# Out:
#                         mean_price  mean_rating
# category          type
# ART_AND_DESIGN    Free      0.0000     4.337931
#                   Paid      1.9900     4.733333
# AUTO_AND_VEHICLES Free      0.0000     4.184722
#                   Paid      4.4900     4.600000
# BEAUTY            Free      0.0000     4.278571
# ...                            ...          ...
# TRAVEL_AND_LOCAL  Paid      4.1625     4.100000
# VIDEO_PLAYERS     Free      0.0000     4.043056
#                   Paid      2.6150     4.100000
# WEATHER           Free      0.0000     4.229231
#                   Paid      4.0525     4.371429
#
# [63 rows x 2 columns]
